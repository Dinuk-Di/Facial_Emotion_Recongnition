# %%
import cv2
import numpy as np
import tensorflow as tf
print(tf.__version__)

model = tf.keras.models.load_model('cnn_Bilstm_model.h5')
model.export('cnn_Bilstm_model4_savedmodel')
# Out:
# 2.19.0
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# INFO:tensorflow:Assets written to: cnn_Bilstm_model4_savedmodel\assets
# INFO:tensorflow:Assets written to: cnn_Bilstm_model4_savedmodel\assets
# Saved artifact at 'cnn_Bilstm_model4_savedmodel'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): List[TensorSpec(shape=(None, 30, 64, 64, 3), dtype=tf.float32, name='input_layer_1')]
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   1961696288608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1961696300016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1961696317504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1961696297728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   1961696299840: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
